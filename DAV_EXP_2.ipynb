# %%
df=pd.read_csv('/content/sample_data/height-weight.csv')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
plt.scatter(df['Weight'],df['Height'])
plt.xlabel("Weight")
plt.ylabel("Height")
# Out:
# Text(0, 0.5, 'Height')

# %%
## Seaborn for visualization
import seaborn as sns
sns.pairplot(df)

# %%
X=df[['Weight']]
y=df['Height']
X_series=df['Weight']
np.array(X_series).shape
# Out:
# (23,)

# %%
np.array(y).shape
# Out:
# (23,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)
## Standardization
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)
X_test
# Out:
# array([[ 0.33497168],
#        [ 0.33497168],
#        [-1.6641678 ],
#        [ 1.36483141],
#        [-0.45256812],
#        [ 1.97063125]])

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression(n_jobs=-1)
regression.fit(X_train,y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
print("Coefficient or slope:",regression.coef_)
print("Intercept:",regression.intercept_)
# Out:
# Coefficient or slope: [17.2982057]
# Intercept: 156.47058823529412

# %%
plt.scatter(X_train,y_train)
plt.plot(X_train,regression.predict(X_train))

# %%
y_pred=regression.predict(X_test)

# %%
y_pred
# Out:
# array([162.26499721, 162.26499721, 127.68347133, 180.07972266,
#        148.64197186, 190.55897293])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 114.84069295228699
# 9.66512588679501
# 10.716374991212605

# %%
#R
vehicles <- read.csv("/content/sample_data/vehicles.csv") #Upload the data

# %%
vehicles
# Out:
#     X   car_name                                            mileage.kmpl.
# 1    0  2017 Mercedes-Benz S-Class S400                       7.81
# 2    1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI    17.40
# 3    2  2018 BMW X1 sDrive 20d xLine                         20.68
# 4    3  2019 Kia Seltos GTX Plus                             16.50
# 5    4  2019 Skoda Superb LK 1.8 TSI AT                      14.67
# 6    5  2017 Honda Jazz 1.2 S i VTEC                         18.70
# 7    6  2018 Hyundai Grand i10 1.2 Kappa Sportz BSIV         18.90
# 8    7  2018 Hyundai Creta 1.6 SX                            15.80
# 9    8  2015 Mercedes-Benz S-Class S 350 CDI                 13.50
# 10   9  2019 Tata Nexon 1.2 Revotron XZ Plus                 17.00
# 11  10  2020 Honda City VX CVT                               17.40
# 12  11  2021 Renault Duster RXS                              16.42
# 13  12  2014 BMW 3 Series 320d Prestige                      18.88
# ...

# %%
lmTemp = lm(price~engine, data = vehicles) #Create the linear regression

# %%
plot(vehicles$price , pch = 16, col = "blue") #Plot the results
# Out:
# plot without title

# %%
abline(lmTemp, col = "red")
# Out:
# Error in int_abline(a = a, b = b, h = h, v = v, untf = untf, ...): plot.new has not been called yet
# Traceback:
#
# 1. abline(lmTemp, col = "red")
# 2. int_abline(a = a, b = b, h = h, v = v, untf = untf, ...)

# %%
# Fit a linear regression model
lmTemp <- lm(price~engine, data = vehicles)

# Plot the results
plot(vehicles$engine, vehicles$price, pch = 16, col = "blue", main = "Price Plot", xlab = "Engine", ylab = "Price")

# Add regression line
abline(lmTemp, col = "red")
# Out:
# Plot with title “Price Plot”

# %%
plot(vehicles$engine, vehicles$price, pch = 16, col = "blue", main = "Zoomed Price Plot", xlab = "Independent Variable", ylab = "Price", xlim = c(0, 5000), )
# Out:
# Plot with title “Zoomed Price Plot”

# %%
summary(lmTemp)
# Out:
# Call:
# lm(formula = price ~ engine, data = vehicles)
#
# Residuals:
#    Min     1Q Median     3Q    Max
#   -774   -708   -688   -634  69222
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 781.72633  479.52007   1.630    0.104
# engine       -0.05720    0.07767  -0.736    0.462
#
# Residual standard error: 6449 on 233 degrees of freedom
# Multiple R-squared:  0.002322,	Adjusted R-squared:  -0.00196
# F-statistic: 0.5423 on 1 and 233 DF,  p-value: 0.4622
